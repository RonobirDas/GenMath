# %% [markdown]
# # First steps into sympy
#
# Here we go!

# %%
import numpy as np
import scipy as sp
import control 
import sympy
from __future__ import division
from sympy import *
x, y, z, t, s, w = symbols('x y z t s w')
k, m, n = symbols('k m n', integer=True)
f, g, h = symbols('f g h', cls=Function)
init_printing()
import scipy.signal as signal
from IPython.display import Audio, display
from IPython.display import Image, SVG
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
s = fourier_series(Heaviside(t) - Heaviside(t-1), (t, 0, 2))
s.truncate(4)
# Out:
# 2⋅sin(π⋅t)   2⋅sin(3⋅π⋅t)   2⋅sin(5⋅π⋅t)   1
# ────────── + ──────────── + ──────────── + ─
#     π            3⋅π            5⋅π        2

# %% [markdown]
# [Source](https://stackoverflow.com/questions/36177131/sympy-extract-fourier-series-coefficients)

# %%
iter = s.truncate(None)
cosine_coeffs = []
sine_coeffs = [0]       # there is no sine term for k = 0
amplitude = []
phase = []
for k in range(0, 4):
    term = next(iter)
    #print(term)
    cosine_coeffs.append(term.subs(t, 0))
    if k > 0:
        sine_coeffs.append(term.subs(t, k/2)) #correction, we only care about 1/2 * pi terms since sin(n*pi/2) = 1, which is what we care about
for l in range(len(sine_coeffs)):
    amplitude.append(sqrt((sine_coeffs[l])**2 + (cosine_coeffs[l])**2))
    phase.append(-atan2(sine_coeffs[l],cosine_coeffs[l]))
    print(phase[l])
# Out:
# 0
# -pi/2
# nan
# -pi/2

# %%
print(latex(amplitude))
# Out:
# \left [ \frac{1}{2}, \quad \frac{2}{\pi}, \quad 0, \quad \frac{2}{3 \pi}\right ]

# %% [markdown]
# $$A = \left [ \frac{1}{2}, \quad \frac{2}{\pi}, \quad 0, \quad \frac{2}{3 \pi}\right ]$$

# %%
print("This is the input waveform")
p1 = plot(Heaviside(t+2) - Heaviside(t+1) + Heaviside(t) - Heaviside(t-1) + Heaviside(t-2) - Heaviside(t-3), (t,-2.1,3.1))
# Out:
# This is the input waveform

# %%
plot(s.truncate(4),(t,0,2))

# %%
plot(s.truncate(11),(t,0,2))

# %% [markdown]
# You can see the Gibbs Phenomena in full effect

# %%
amplitude
# Out:
# ⎡     2      2 ⎤
# ⎢1/2, ─, 0, ───⎥
# ⎣     π     3⋅π⎦

# %%
plt.stem(amplitude[1:4])
#Have to figure out how to do proper stem plots, plotting radian values. Skip the first value of the amplitude since that's just the DC component
# Out:
# <Container object of 3 artists>

# %%
plt.stem(phase)
# Out:
# <Container object of 3 artists>

# %%
inverse_laplace_transform(exp(-x*z)/z, z, t) # testing out the laplace transform
# Out:
# Heaviside(t - x)

# %% [markdown]
# Now to test the complex fourier series. We will try to model the sinc function

# %%
function = Heaviside(t+9) - Heaviside(t+7) + Heaviside(t+5) - Heaviside(t+3) + Heaviside(t+1) - Heaviside(t-1) + Heaviside(t-3) - Heaviside(t-5) + Heaviside(t-7) - Heaviside(t-9)
plot(function)

# %%
fsfunc = fourier_series(Heaviside(t-3) - Heaviside(t-5), (t, 3, 6))
fsfunc
plot(fsfunc.truncate(10), (t, 0, 6.1))

# %%
fsfunc
# Out:
#      ⎛2⋅π⋅t⎞        ⎛4⋅π⋅t⎞         ⎛2⋅π⋅t⎞         ⎛4⋅π⋅t⎞
# 3⋅sin⎜─────⎟   3⋅sin⎜─────⎟   √3⋅cos⎜─────⎟   √3⋅cos⎜─────⎟
#      ⎝  3  ⎠        ⎝  3  ⎠         ⎝  3  ⎠         ⎝  3  ⎠   2
# ──────────── + ──────────── - ───────────── + ───────────── + ─ + …
#     2⋅π            4⋅π             2⋅π             4⋅π        3

# %%
iter = fsfunc.truncate(None)
cosine_coeffs = []
sine_coeffs = [0]       # there is no sine term for k = 0
amplitude = []
phase = []
for k in range(0, 11):
    term = next(iter)
    #print(term)
    cosine_coeffs.append(term.subs(t, 0))
    if k > 0:
        sine_coeffs.append(term.subs(t, k/2)) #correction, we only care about 1/2 * pi terms since sin(n*pi/2) = 1, which is what we care about
for l in range(len(sine_coeffs)):
    amplitude.append(sqrt((sine_coeffs[l])**2 + (cosine_coeffs[l])**2))
    phase.append(-atan2(cosine_coeffs[l],sine_coeffs[l]))
plt.stem(amplitude)
# Out:
# <Container object of 3 artists>

# %%
complexfs = []
for o in range(len(amplitude)):
    complexfs.append(cosine_coeffs[o] - I*sine_coeffs[o])

# %%
complexfs
# Out:
# ⎡        √3     ⎛  √3⋅cos(0.333333333333333⋅π)   3⋅sin(0.333333333333333⋅π)⎞
# ⎢2/3, - ─── - ⅈ⋅⎜- ─────────────────────────── + ──────────────────────────⎟,
# ⎣       2⋅π     ⎝              2⋅π                          2⋅π            ⎠
#
#  √3     ⎛3⋅sin(1.33333333333333⋅π)   √3⋅cos(1.33333333333333⋅π)⎞        √3
# ─── - ⅈ⋅⎜───────────────────────── + ──────────────────────────⎟, 0, - ─── - ⅈ
# 4⋅π     ⎝           4⋅π                         4⋅π            ⎠       8⋅π
#
#  ⎛3⋅sin(1.33333333333333⋅π)   √3⋅cos(1.33333333333333⋅π)⎞   √3      ⎛√3⋅cos(0.
# ⋅⎜───────────────────────── - ──────────────────────────⎟, ──── - ⅈ⋅⎜─────────
#  ⎝           8⋅π                         8⋅π            ⎠  10⋅π     ⎝
#
# 333333333333334⋅π)   3⋅sin(0.333333333333334⋅π)⎞        √3      ⎛  √3⋅cos(0.33
# ────────────────── + ──────────────────────────⎟, 0, - ──── - ⅈ⋅⎜- ───────────
#    10⋅π                         10⋅π           ⎠       14⋅π     ⎝
#
# 3333333333336⋅π)   3⋅sin(0.333333333333336⋅π)⎞   √3      ⎛3⋅sin(1.333333333333
# ──────────────── + ──────────────────────────⎟, ──── - ⅈ⋅⎜────────────────────
#  14⋅π                         14⋅π           ⎠  16⋅π     ⎝           16⋅π
#
# 33⋅π)   √3⋅cos(1.33333333333333⋅π)⎞        √3      ⎛3⋅sin(1.33333333333334⋅π)
# ───── + ──────────────────────────⎟, 0, - ──── - ⅈ⋅⎜─────────────────────────
#                    16⋅π           ⎠       20⋅π     ⎝           20⋅π
#
#   √3⋅cos(1.33333333333334⋅π)⎞⎤
# - ──────────────────────────⎟⎥
#              20⋅π           ⎠⎦

# %%
cfss = []
for i in range(len(complexfs)):
    cfss.append(abs(complexfs[i]))
cfss
# Out:
# ⎡           __________________________________________________________________
# ⎢          ╱                                                                 2
# ⎢         ╱    3⋅√3⋅sin(0.333333333333333⋅π)⋅cos(0.333333333333333⋅π)   3⋅cos
# ⎢2/3,    ╱   - ────────────────────────────────────────────────────── + ──────
# ⎢       ╱                                  2
# ⎣     ╲╱                                2⋅π
#
# ___________________________________________________________        ___________
#                                     2                             ╱      2
# (0.333333333333333⋅π)    3     9⋅sin (0.333333333333333⋅π)       ╱  3⋅cos (1.3
# ───────────────────── + ──── + ─────────────────────────── ,    ╱   ──────────
#          2                 2                  2                ╱
#       4⋅π               4⋅π                4⋅π               ╲╱
#
# ______________________________________________________________________________
#
# 3333333333333⋅π)     3     3⋅√3⋅sin(1.33333333333333⋅π)⋅cos(1.33333333333333⋅π
# ──────────────── + ───── + ───────────────────────────────────────────────────
#     2                  2                              2
# 16⋅π               16⋅π                            8⋅π
#
# _______________________________           ____________________________________
#          2                               ╱
# )   9⋅sin (1.33333333333333⋅π)          ╱    3⋅√3⋅sin(1.33333333333333⋅π)⋅cos(
# ─ + ────────────────────────── , 0,    ╱   - ─────────────────────────────────
#                   2                   ╱                                 2
#               16⋅π                  ╲╱                              32⋅π
#
# ______________________________________________________________________________
#                            2                                    2
# 1.33333333333333⋅π)   3⋅cos (1.33333333333333⋅π)     3     9⋅sin (1.3333333333
# ─────────────────── + ────────────────────────── + ───── + ───────────────────
#                                     2                  2                 2
#                                 64⋅π               64⋅π              64⋅π
#
# ________        ______________________________________________________________
#                ╱      2
# 3333⋅π)       ╱  3⋅cos (0.333333333333334⋅π)     3      3⋅√3⋅sin(0.33333333333
# ─────── ,    ╱   ─────────────────────────── + ────── + ──────────────────────
#             ╱                    2                  2
#           ╲╱                100⋅π              100⋅π
#
# _______________________________________________________________           ____
#                                         2                                ╱
# 3334⋅π)⋅cos(0.333333333333334⋅π)   9⋅sin (0.333333333333334⋅π)          ╱    3
# ──────────────────────────────── + ─────────────────────────── , 0,    ╱   - ─
#       2                                            2                  ╱
#   50⋅π                                        100⋅π                 ╲╱
#
# ______________________________________________________________________________
#                                                              2
# ⋅√3⋅sin(0.333333333333336⋅π)⋅cos(0.333333333333336⋅π)   3⋅cos (0.3333333333333
# ───────────────────────────────────────────────────── + ──────────────────────
#                            2                                            2
#                        98⋅π                                        196⋅π
#
# _____________________________________________        _________________________
#                       2                             ╱      2
# 36⋅π)     3      9⋅sin (0.333333333333336⋅π)       ╱  3⋅cos (1.33333333333333⋅
# ───── + ────── + ─────────────────────────── ,    ╱   ────────────────────────
#              2                   2               ╱                   2
#         196⋅π               196⋅π              ╲╱               256⋅π
#
# ______________________________________________________________________________
#                                                                           2
# π)     3      3⋅√3⋅sin(1.33333333333333⋅π)⋅cos(1.33333333333333⋅π)   9⋅sin (1.
# ── + ────── + ──────────────────────────────────────────────────── + ─────────
#           2                               2
#      256⋅π                           128⋅π
#
# __________________           _________________________________________________
#                             ╱
# 33333333333333⋅π)          ╱    3⋅√3⋅sin(1.33333333333334⋅π)⋅cos(1.33333333333
# ───────────────── , 0,    ╱   - ──────────────────────────────────────────────
#       2                  ╱                                  2
#  256⋅π                 ╲╱                              200⋅π
#
# __________________________________________________________________________⎤
#               2                                     2                     ⎥
# 334⋅π)   3⋅cos (1.33333333333334⋅π)     3      9⋅sin (1.33333333333334⋅π) ⎥
# ────── + ────────────────────────── + ────── + ────────────────────────── ⎥
#                         2                  2                  2           ⎥
#                    400⋅π              400⋅π              400⋅π            ⎦

# %%
plt.stem(cfss)
# Out:
# <Container object of 3 artists>

# %%
plt.stem(phase)
# Out:
# <Container object of 3 artists>

# %% [markdown]
# For an RC, LC, RL, and RLC circuits find the regular differential equation, the laplace transform, the fourier transform and the fourier series representation. Find the impluse
# response, step response, ramp response, square wave, sawtooth, triangle, cosine, sine and exponential response to the circuit. Try a series and parrallel resonance example. Find omega0 and the half power frequencies as well as the power, along with the quality factor and finally the bandwidth. Remember to convert from radians to hertz https://en.wikipedia.org/wiki/Radian_per_second
# https://en.wikipedia.org/wiki/Q_factor
# https://en.wikipedia.org/wiki/RLC_circuit
# https://en.wikipedia.org/wiki/Oscillator_phase_noise
# http://sim.okawa-denshi.jp/en/CRlowkeisan.htm

# %%
#Series RC circuit, find impulse response aka the transfer function
#First we need to construct the input waveforms. The Impulse, step, ramp etc transformed counter part
# Out:
#  1
# ────
# 20⋅π

# %%
laplace_transform(Heaviside(t), t, s)
# Out:
# (1/s, 0, True)

# %%
fourier_series(Heaviside(t), (t,0,1)) #just to show this is not a continuous periodic signal, we can't exactly use a discrete series representation on it like previously
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-7-77e08dcbcb3f> in <module>()
# ----> 1 fourier_series(Heaviside(t), (t,0,1))
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/IPython/core/displayhook.pyc in __call__(self, result)
#     244             self.start_displayhook()
#     245             self.write_output_prompt()
# --> 246             format_dict, md_dict = self.compute_format_data(result)
#     247             self.update_user_ns(result)
#     248             self.fill_exec_result(result)
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/IPython/core/displayhook.pyc in compute_format_data(self, result)
#     148
#     149         """
# --> 150         return self.shell.display_formatter.format(result)
#     151
#     152     # This can be set to True by the write_output_prompt method in a subclass
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     171             md = None
#     172             try:
# --> 173                 data = formatter(obj)
#     174             except:
#     175                 # FIXME: log the exception
#
# <decorator-gen-10> in __call__(self, obj)
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     215     """show traceback on failed format call"""
#     216     try:
# --> 217         r = method(self, *args, **kwargs)
#     218     except NotImplementedError:
#     219         # don't warn on NotImplementedErrors
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     366                 if cls in self.type_pprinters:
#     367                     # printer registered in self.type_pprinters
# --> 368                     return self.type_pprinters[cls](obj, self, cycle)
#     369                 else:
#     370                     # deferred printer
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _print_plain(arg, p, cycle)
#      66         """caller for pretty, for use in IPython 0.11"""
#      67         if _can_print_latex(arg):
# ---> 68             p.text(stringify_func(arg))
#      69         else:
#      70             p.text(IPython.lib.pretty.pretty(arg))
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/printing/pretty/pretty.pyc in pretty(expr, **settings)
#    2162
#    2163     try:
# -> 2164         return pp.doprint(expr)
#    2165     finally:
#    2166         pretty_use_unicode(uflag)
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/printing/pretty/pretty.pyc in doprint(self, expr)
#      60
#      61     def doprint(self, expr):
# ---> 62         return self._print(expr).render(**self._settings)
#      63
#      64     # empty op so _print(stringPict) returns the same
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/printing/printer.pyc in _print(self, expr, *args, **kwargs)
#     255                 printmethod = '_print_' + cls.__name__
#     256                 if hasattr(self, printmethod):
# --> 257                     return getattr(self, printmethod)(expr, *args, **kwargs)
#     258             # Unknown object, fall back to the emptyPrinter.
#     259             return self.emptyPrinter(expr)
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/printing/pretty/pretty.pyc in _print_FourierSeries(self, s)
#    1702         else:
#    1703             dots = '...'
# -> 1704         return self._print_Add(s.truncate()) + self._print(dots)
#    1705
#    1706     def _print_FormalPowerSeries(self, s):
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/series/fourier.pyc in truncate(self, n)
#     188
#     189         terms = []
# --> 190         for t in self:
#     191             if len(terms) == n:
#     192                 break
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/series/series_class.pyc in __iter__(self)
#      86         while i < self.length:
#      87             pt = self._ith_point(i)
# ---> 88             yield self.term(pt)
#      89             i += 1
#      90
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/series/series_class.pyc in term(self, pt)
#      54         if pt < self.start or pt > self.stop:
#      55             raise IndexError("Index %s out of bounds %s" % (pt, self.interval))
# ---> 56         return self._eval_term(pt)
#      57
#      58     def _eval_term(self, pt):
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/series/fourier.pyc in _eval_term(self, pt)
#     381         if pt == 0:
#     382             return self.a0
# --> 383         return self.an.coeff(pt) + self.bn.coeff(pt)
#     384
#     385     def __neg__(self):
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/series/sequences.pyc in coeff(self, pt)
#     104         if pt < self.start or pt > self.stop:
#     105             raise IndexError("Index %s out of bounds %s" % (pt, self.interval))
# --> 106         return self._eval_coeff(pt)
#     107
#     108     def _eval_coeff(self, pt):
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/series/sequences.pyc in _eval_coeff(self, pt)
#     685     def _eval_coeff(self, pt):
#     686         d = self.variables[0]
# --> 687         return self.formula.subs(d, pt)
#     688
#     689     def _add(self, other):
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/core/basic.pyc in subs(self, *args, **kwargs)
#     914             rv = self
#     915             for old, new in sequence:
# --> 916                 rv = rv._subs(old, new, **kwargs)
#     917                 if not isinstance(rv, Basic):
#     918                     break
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/core/basic.pyc in _subs(self, old, new, **hints)
#    1028         rv = self._eval_subs(old, new)
#    1029         if rv is None:
# -> 1030             rv = fallback(self, old, new)
#    1031         return rv
#    1032
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/core/basic.pyc in fallback(self, old, new)
#    1000                 if not hasattr(arg, '_eval_subs'):
#    1001                     continue
# -> 1002                 arg = arg._subs(old, new, **hints)
#    1003                 if not _aresame(arg, args[i]):
#    1004                     hit = True
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/core/basic.pyc in _subs(self, old, new, **hints)
#    1028         rv = self._eval_subs(old, new)
#    1029         if rv is None:
# -> 1030             rv = fallback(self, old, new)
#    1031         return rv
#    1032
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/core/basic.pyc in fallback(self, old, new)
#    1005                     args[i] = arg
#    1006             if hit:
# -> 1007                 rv = self.func(*args)
#    1008                 hack2 = hints.get('hack2', False)
#    1009                 if hack2 and self.is_Mul and not rv.is_Mul:  # 2-arg hack
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/core/function.pyc in __new__(cls, *args, **options)
#     409
#     410         n = len(args)
# --> 411         if n not in cls.nargs:
#     412             # XXX: exception message must be in exactly this format to
#     413             # make it work with NumPy's functions like vectorize(). See,
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/sets/sets.pyc in __contains__(self, other)
#     577
#     578     def __contains__(self, other):
# --> 579         symb = sympify(self.contains(other))
#     580         if not (symb is S.true or symb is S.false):
#     581             raise TypeError('contains did not evaluate to a bool: %r' % symb)
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/sets/sets.pyc in contains(self, other)
#     305         """
#     306         other = sympify(other, strict=True)
# --> 307         ret = sympify(self._contains(other))
#     308         if ret is None:
#     309             ret = Contains(other, self, evaluate=False)
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/sets/sets.pyc in _contains(self, other)
#    2001         r = false
#    2002         for e in self._elements:
# -> 2003             t = Eq(e, other, evaluate=True)
#    2004             if isinstance(t, Eq):
#    2005                 t = t.simplify()
#
# /home/devbox/anaconda2/lib/python2.7/site-packages/sympy/core/relational.pyc in __new__(cls, lhs, rhs, **options)
#     307             # If expressions have the same structure, they must be equal.
#     308             if lhs == rhs:
# --> 309                 return S.true
#     310             elif all(isinstance(i, BooleanAtom) for i in (rhs, lhs)):
#     311                 return S.false
#
# KeyboardInterrupt:

# %%
fourier_transform(Heaviside(t),t,w) #here w represent omega
# Out:
#  -ⅈ
# ─────
# 2⋅π⋅w

# %%
laplace_transform(function, t, s, noconds=True)
# Out:
# ⎛ 9⋅s    8⋅s    6⋅s    4⋅s    2⋅s    ⎞  -9⋅s
# ⎝ℯ    - ℯ    + ℯ    - ℯ    + ℯ    - 1⎠⋅ℯ
# ────────────────────────────────────────────
#                      s

# %%
fourier_transform(function, t, w)
# Out:
#   ⎛   36⋅ⅈ⋅π⋅w    32⋅ⅈ⋅π⋅w    28⋅ⅈ⋅π⋅w    24⋅ⅈ⋅π⋅w    20⋅ⅈ⋅π⋅w    16⋅ⅈ⋅π⋅w
# ⅈ⋅⎝- ℯ         + ℯ         - ℯ         + ℯ         - ℯ         + ℯ         - ℯ
# ──────────────────────────────────────────────────────────────────────────────
#                                                            2⋅π⋅w
#
# 12⋅ⅈ⋅π⋅w    8⋅ⅈ⋅π⋅w    4⋅ⅈ⋅π⋅w    ⎞  -18⋅ⅈ⋅π⋅w
#          + ℯ        - ℯ        + 1⎠⋅ℯ
# ──────────────────────────────────────────────

# %% [markdown]
# Notice the differences in values here. We now attempt to do this for all three essential inputs (impulse, step, ramp), and finally we also introduce the fourier series for the rest of the input signals

# %%
plot(laplace_transform(function, t, s, noconds=True), (s, -20, 10))

# %%
plot(laplace_transform(function, t, s, noconds=True), (s, 0, 10))

# %% [markdown]
# For anyones interest the laplace transform of the input signals are shown above
